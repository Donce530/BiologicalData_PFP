# %% [markdown]
# # Multi-Layer Perceptron
#
# This note book will be used to test a multilayer perceptron on each of the 3 ontologies.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
import itertools
import pprint
import yaml

# %%
print("TensorFlow v" + tf.__version__)
print("Numpy v" + np.__version__)
# Out:
# TensorFlow v2.15.0
# Numpy v1.25.2

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
config_path = './config.yaml'
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

# %%
USE_75_PERCENT_DATA = config['use_75_percent_datasets']
partial_dataset_prefix = '75percent_' if USE_75_PERCENT_DATA else ''
BP_train_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_embeddings_BiologicalProcesses.pkl")
CC_train_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_embeddings_CellularComponent.pkl")
MF_train_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_embeddings_MolecularFunction.pkl")
BP_label_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_labels_BiologicalProcesses.pkl")
CC_label_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_labels_CellularComponent.pkl")
MF_label_df = pd.read_pickle(f"{config['directories']['preprocessed_data']}/{partial_dataset_prefix}train_labels_MolecularFunction.pkl")

# %%
train_data_dict = {'Biological Processes': [BP_train_df, BP_label_df],
                   'Cellular Component': [CC_train_df, CC_label_df],
                   'Molecular Function': [MF_train_df, MF_label_df]
}

# %%
num_labels = 1500
num_folds = config['num_folds']

# %% [markdown]
# ## Architecture: Dense layers of the same size with linear activation function

# %%
BATCH_SIZE = config['batch_size']

# %%
def model_training(dataset_name, data):
  train = data[0]
  label = data[1]

  INPUT_SHAPE = [train.shape[1]]

  act_param = 'linear'
  unit_param = 1024

  best_f1 = 0
  print('=======================================================================')
  print(f'Training for {dataset_name}')
  
  model_root_path = f'{config["directories"]["models"]}/MLPMod'

  kfold = KFold(n_splits=num_folds, shuffle=True)
  fold_no = 1

  for train_fold, test_fold in kfold.split(train, label):

    model = tf.keras.Sequential([
        tf.keras.layers.BatchNormalization(input_shape=INPUT_SHAPE),
        tf.keras.layers.Dense(units = unit_param, activation = act_param),
        tf.keras.layers.Dense(units = unit_param, activation = act_param),
        tf.keras.layers.Dense(units = unit_param, activation = act_param),
        tf.keras.layers.Dense(units = num_labels, activation = 'sigmoid')
        ])

    # Compile model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['binary_accuracy',
                tf.keras.metrics.AUC(),
                tf.keras.metrics.Precision(),
                tf.keras.metrics.Recall(),
                ] # tf.keras.metrics.F1Score() not appropriate as it is calculated batchwise
        )

    print(f'Training for fold {fold_no} ...')

    # Fit the data to the model
    history = model.fit(
        train.iloc[train_fold], label.iloc[train_fold],
        batch_size=BATCH_SIZE,
        epochs=5
        )

    # Generate metrics
    scores = model.evaluate(train.iloc[test_fold], label.iloc[test_fold], verbose=0)
    precision = scores[3]
    print(f'{model.metrics_names[3]} is {precision}')
    recall = scores[4]
    print(f'{model.metrics_names[4]} is {recall}')
    F1_score = 2*precision*recall / (precision + recall)
    print(f'Score for fold {fold_no}: F1 score of {F1_score}; {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')

    if F1_score > best_f1:
      best_f1 = F1_score
      if dataset_name == 'Biological Processes':
        tf.keras.models.save_model(
            model,
            f'{model_root_path}/best_BP_model'
        )
        print(f'Current best model for Biological Processes has an F1 score of {F1_score}')

      elif dataset_name == 'Molecular Function':
        tf.keras.models.save_model(
            model,
            f'{model_root_path}/best_MF_model'
        )
        print(f'Current best model for Molecular Function has an F1 score of {F1_score}')

      else:
        tf.keras.models.save_model(
            model,
            f'{model_root_path}/best_CC_model'
        )
        print(f'Current best model for Cellular Component has an F1 score of {F1_score}')

    fold_no += 1

# %%
for dataset in train_data_dict:
  dataset_name = dataset
  data = train_data_dict[dataset]
  model_training(dataset_name, data)
# Out:
# =======================================================================
# Training for Biological Processes
# Training for fold 1 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1271 - binary_accuracy: 0.9523 - auc_9: 0.8492 - precision_9: 0.2076 - recall_9: 0.2383
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0810 - binary_accuracy: 0.9745 - auc_9: 0.9150 - precision_9: 0.6345 - recall_9: 0.2494
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0789 - binary_accuracy: 0.9747 - auc_9: 0.9216 - precision_9: 0.6413 - recall_9: 0.2584
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9748 - auc_9: 0.9249 - precision_9: 0.6433 - recall_9: 0.2646
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0771 - binary_accuracy: 0.9749 - auc_9: 0.9271 - precision_9: 0.6475 - recall_9: 0.2676
# precision_9 is 0.6686819195747375
# recall_9 is 0.2641104459762573
# Score for fold 1: F1 score of 0.37866064628610835; loss of 0.07494833320379257; binary_accuracy of 97.52647280693054%
# Current best model for Biological Processes has an F1 score of 0.37866064628610835
# Training for fold 2 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1282 - binary_accuracy: 0.9524 - auc_10: 0.8471 - precision_10: 0.2083 - recall_10: 0.2387
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0811 - binary_accuracy: 0.9745 - auc_10: 0.9146 - precision_10: 0.6359 - recall_10: 0.2496
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0791 - binary_accuracy: 0.9747 - auc_10: 0.9211 - precision_10: 0.6412 - recall_10: 0.2579
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9748 - auc_10: 0.9248 - precision_10: 0.6448 - recall_10: 0.2641
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0771 - binary_accuracy: 0.9749 - auc_10: 0.9271 - precision_10: 0.6475 - recall_10: 0.2678
# precision_10 is 0.6549568772315979
# recall_10 is 0.2763316333293915
# Score for fold 2: F1 score of 0.3886771963646439; loss of 0.07508324831724167; binary_accuracy of 97.51951694488525%
# Current best model for Biological Processes has an F1 score of 0.3886771963646439
# Training for fold 3 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1279 - binary_accuracy: 0.9516 - auc_11: 0.8491 - precision_11: 0.2045 - recall_11: 0.2414
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0811 - binary_accuracy: 0.9745 - auc_11: 0.9147 - precision_11: 0.6348 - recall_11: 0.2488
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0788 - binary_accuracy: 0.9747 - auc_11: 0.9218 - precision_11: 0.6429 - recall_11: 0.2588
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9748 - auc_11: 0.9249 - precision_11: 0.6447 - recall_11: 0.2643
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0771 - binary_accuracy: 0.9749 - auc_11: 0.9271 - precision_11: 0.6466 - recall_11: 0.2680
# precision_11 is 0.6895142197608948
# recall_11 is 0.24250899255275726
# Score for fold 3: F1 score of 0.3588180993259276; loss of 0.07490575313568115; binary_accuracy of 97.52675890922546%
# Training for fold 4 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1259 - binary_accuracy: 0.9528 - auc_12: 0.8509 - precision_12: 0.2110 - recall_12: 0.2391
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0810 - binary_accuracy: 0.9745 - auc_12: 0.9149 - precision_12: 0.6359 - recall_12: 0.2485
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0790 - binary_accuracy: 0.9747 - auc_12: 0.9213 - precision_12: 0.6422 - recall_12: 0.2587
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0778 - binary_accuracy: 0.9748 - auc_12: 0.9250 - precision_12: 0.6447 - recall_12: 0.2641
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0772 - binary_accuracy: 0.9749 - auc_12: 0.9267 - precision_12: 0.6455 - recall_12: 0.2683
# precision_12 is 0.6697902679443359
# recall_12 is 0.2652110457420349
# Score for fold 4: F1 score of 0.3799690434423064; loss of 0.074662946164608; binary_accuracy of 97.53004908561707%
# Training for fold 5 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1267 - binary_accuracy: 0.9524 - auc_13: 0.8498 - precision_13: 0.2086 - recall_13: 0.2390
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0812 - binary_accuracy: 0.9744 - auc_13: 0.9146 - precision_13: 0.6332 - recall_13: 0.2486
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0789 - binary_accuracy: 0.9747 - auc_13: 0.9218 - precision_13: 0.6412 - recall_13: 0.2579
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9748 - auc_13: 0.9247 - precision_13: 0.6439 - recall_13: 0.2641
# Epoch 5/5
# 244/244 [==============================] - 14s 58ms/step - loss: 0.0772 - binary_accuracy: 0.9749 - auc_13: 0.9270 - precision_13: 0.6449 - recall_13: 0.2672
# precision_13 is 0.648483395576477
# recall_13 is 0.2841317355632782
# Score for fold 5: F1 score of 0.3951355849093578; loss of 0.07536159455776215; binary_accuracy of 97.51763939857483%
# Current best model for Biological Processes has an F1 score of 0.3951355849093578
# Training for fold 6 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1262 - binary_accuracy: 0.9527 - auc_14: 0.8499 - precision_14: 0.2114 - recall_14: 0.2403
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0811 - binary_accuracy: 0.9745 - auc_14: 0.9147 - precision_14: 0.6352 - recall_14: 0.2488
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0789 - binary_accuracy: 0.9747 - auc_14: 0.9218 - precision_14: 0.6423 - recall_14: 0.2591
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9749 - auc_14: 0.9247 - precision_14: 0.6447 - recall_14: 0.2649
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0771 - binary_accuracy: 0.9749 - auc_14: 0.9271 - precision_14: 0.6470 - recall_14: 0.2675
# precision_14 is 0.649968147277832
# recall_14 is 0.2789756655693054
# Score for fold 6: F1 score of 0.39039023453944793; loss of 0.07540909945964813; binary_accuracy of 97.51375317573547%
# Training for fold 7 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1278 - binary_accuracy: 0.9519 - auc_15: 0.8492 - precision_15: 0.2063 - recall_15: 0.2408
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0808 - binary_accuracy: 0.9745 - auc_15: 0.9159 - precision_15: 0.6364 - recall_15: 0.2485
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0788 - binary_accuracy: 0.9747 - auc_15: 0.9222 - precision_15: 0.6418 - recall_15: 0.2582
# Epoch 4/5
# 244/244 [==============================] - 14s 58ms/step - loss: 0.0778 - binary_accuracy: 0.9749 - auc_15: 0.9252 - precision_15: 0.6457 - recall_15: 0.2645
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0770 - binary_accuracy: 0.9749 - auc_15: 0.9274 - precision_15: 0.6467 - recall_15: 0.2678
# precision_15 is 0.6380202174186707
# recall_15 is 0.2844894826412201
# Score for fold 7: F1 score of 0.3935135675132575; loss of 0.0757410004734993; binary_accuracy of 97.49754667282104%
# Training for fold 8 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1273 - binary_accuracy: 0.9523 - auc_16: 0.8502 - precision_16: 0.2077 - recall_16: 0.2390
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0809 - binary_accuracy: 0.9745 - auc_16: 0.9155 - precision_16: 0.6360 - recall_16: 0.2484
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0790 - binary_accuracy: 0.9747 - auc_16: 0.9217 - precision_16: 0.6395 - recall_16: 0.2577
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9749 - auc_16: 0.9249 - precision_16: 0.6449 - recall_16: 0.2644
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0771 - binary_accuracy: 0.9749 - auc_16: 0.9271 - precision_16: 0.6459 - recall_16: 0.2672
# precision_16 is 0.6541182398796082
# recall_16 is 0.27958914637565613
# Score for fold 8: F1 score of 0.39173806057198296; loss of 0.07490769028663635; binary_accuracy of 97.52232432365417%
# Training for fold 9 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 57ms/step - loss: 0.1259 - binary_accuracy: 0.9532 - auc_17: 0.8506 - precision_17: 0.2130 - recall_17: 0.2379
# Epoch 2/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0810 - binary_accuracy: 0.9745 - auc_17: 0.9149 - precision_17: 0.6374 - recall_17: 0.2492
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0791 - binary_accuracy: 0.9747 - auc_17: 0.9212 - precision_17: 0.6412 - recall_17: 0.2591
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9749 - auc_17: 0.9248 - precision_17: 0.6452 - recall_17: 0.2639
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0769 - binary_accuracy: 0.9750 - auc_17: 0.9275 - precision_17: 0.6489 - recall_17: 0.2687
# precision_17 is 0.6428923606872559
# recall_17 is 0.29231467843055725
# Score for fold 9: F1 score of 0.4018936253025419; loss of 0.0749492272734642; binary_accuracy of 97.51707315444946%
# Current best model for Biological Processes has an F1 score of 0.4018936253025419
# Training for fold 10 ...
# Epoch 1/5
# 244/244 [==============================] - 15s 58ms/step - loss: 0.1296 - binary_accuracy: 0.9511 - auc_18: 0.8464 - precision_18: 0.2004 - recall_18: 0.2392
# Epoch 2/5
# 244/244 [==============================] - 14s 58ms/step - loss: 0.0810 - binary_accuracy: 0.9745 - auc_18: 0.9151 - precision_18: 0.6350 - recall_18: 0.2478
# Epoch 3/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0791 - binary_accuracy: 0.9747 - auc_18: 0.9212 - precision_18: 0.6407 - recall_18: 0.2582
# Epoch 4/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0779 - binary_accuracy: 0.9748 - auc_18: 0.9249 - precision_18: 0.6452 - recall_18: 0.2636
# Epoch 5/5
# 244/244 [==============================] - 14s 57ms/step - loss: 0.0772 - binary_accuracy: 0.9749 - auc_18: 0.9270 - precision_18: 0.6466 - recall_18: 0.2683
# precision_18 is 0.6770481467247009
# recall_18 is 0.24632371962070465
# Score for fold 10: F1 score of 0.36122611905775387; loss of 0.07541481405496597; binary_accuracy of 97.51394391059875%
# =======================================================================
# Training for Cellular Component
# Training for fold 1 ...
# Epoch 1/5
# 331/331 [==============================] - 21s 58ms/step - loss: 0.1030 - binary_accuracy: 0.9627 - auc_19: 0.8724 - precision_19: 0.2611 - recall_19: 0.2778
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0683 - binary_accuracy: 0.9793 - auc_19: 0.9225 - precision_19: 0.6966 - recall_19: 0.2878
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0666 - binary_accuracy: 0.9795 - auc_19: 0.9283 - precision_19: 0.7013 - recall_19: 0.2953
# Epoch 4/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0658 - binary_accuracy: 0.9795 - auc_19: 0.9311 - precision_19: 0.7017 - recall_19: 0.2992
# Epoch 5/5
# 331/331 [==============================] - 20s 59ms/step - loss: 0.0653 - binary_accuracy: 0.9796 - auc_19: 0.9325 - precision_19: 0.7016 - recall_19: 0.3016
# precision_19 is 0.7202941179275513
# recall_19 is 0.29845505952835083
# Score for fold 1: F1 score of 0.4220379826579909; loss of 0.06376136839389801; binary_accuracy of 97.9787528514862%
# Current best model for Cellular Component has an F1 score of 0.4220379826579909
# Training for fold 2 ...
# Epoch 1/5
# 331/331 [==============================] - 21s 58ms/step - loss: 0.1031 - binary_accuracy: 0.9626 - auc_20: 0.8731 - precision_20: 0.2599 - recall_20: 0.2776
# Epoch 2/5
# 331/331 [==============================] - 19s 59ms/step - loss: 0.0681 - binary_accuracy: 0.9793 - auc_20: 0.9232 - precision_20: 0.6978 - recall_20: 0.2879
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0665 - binary_accuracy: 0.9795 - auc_20: 0.9284 - precision_20: 0.7020 - recall_20: 0.2950
# Epoch 4/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0657 - binary_accuracy: 0.9795 - auc_20: 0.9314 - precision_20: 0.7019 - recall_20: 0.2994
# Epoch 5/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0652 - binary_accuracy: 0.9796 - auc_20: 0.9331 - precision_20: 0.7032 - recall_20: 0.3014
# precision_20 is 0.7092795372009277
# recall_20 is 0.30099284648895264
# Score for fold 2: F1 score of 0.42263466824409973; loss of 0.06389260292053223; binary_accuracy of 97.96638488769531%
# Current best model for Cellular Component has an F1 score of 0.42263466824409973
# Training for fold 3 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 57ms/step - loss: 0.1032 - binary_accuracy: 0.9621 - auc_21: 0.8730 - precision_21: 0.2548 - recall_21: 0.2769
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0680 - binary_accuracy: 0.9793 - auc_21: 0.9235 - precision_21: 0.6975 - recall_21: 0.2885
# Epoch 3/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0666 - binary_accuracy: 0.9794 - auc_21: 0.9285 - precision_21: 0.7005 - recall_21: 0.2951
# Epoch 4/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0658 - binary_accuracy: 0.9795 - auc_21: 0.9311 - precision_21: 0.7003 - recall_21: 0.2989
# Epoch 5/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0652 - binary_accuracy: 0.9796 - auc_21: 0.9331 - precision_21: 0.7032 - recall_21: 0.3010
# precision_21 is 0.6883030533790588
# recall_21 is 0.3306879997253418
# Score for fold 3: F1 score of 0.44674299981993265; loss of 0.06356809288263321; binary_accuracy of 97.97471165657043%
# Current best model for Cellular Component has an F1 score of 0.44674299981993265
# Training for fold 4 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 58ms/step - loss: 0.1039 - binary_accuracy: 0.9619 - auc_22: 0.8714 - precision_22: 0.2535 - recall_22: 0.2772
# Epoch 2/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0682 - binary_accuracy: 0.9793 - auc_22: 0.9231 - precision_22: 0.6976 - recall_22: 0.2882
# Epoch 3/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0666 - binary_accuracy: 0.9794 - auc_22: 0.9285 - precision_22: 0.6994 - recall_22: 0.2954
# Epoch 4/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0656 - binary_accuracy: 0.9795 - auc_22: 0.9316 - precision_22: 0.7023 - recall_22: 0.2995
# Epoch 5/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0651 - binary_accuracy: 0.9796 - auc_22: 0.9332 - precision_22: 0.7045 - recall_22: 0.3019
# precision_22 is 0.7164338827133179
# recall_22 is 0.3013741374015808
# Score for fold 4: F1 score of 0.42427381026849686; loss of 0.06356995552778244; binary_accuracy of 97.9775071144104%
# Training for fold 5 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 58ms/step - loss: 0.1037 - binary_accuracy: 0.9626 - auc_23: 0.8719 - precision_23: 0.2598 - recall_23: 0.2768
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0681 - binary_accuracy: 0.9793 - auc_23: 0.9234 - precision_23: 0.6984 - recall_23: 0.2875
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0667 - binary_accuracy: 0.9794 - auc_23: 0.9282 - precision_23: 0.7004 - recall_23: 0.2944
# Epoch 4/5
# 331/331 [==============================] - 19s 59ms/step - loss: 0.0657 - binary_accuracy: 0.9795 - auc_23: 0.9311 - precision_23: 0.7010 - recall_23: 0.2990
# Epoch 5/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0652 - binary_accuracy: 0.9796 - auc_23: 0.9332 - precision_23: 0.7027 - recall_23: 0.3016
# precision_23 is 0.7227640748023987
# recall_23 is 0.297808438539505
# Score for fold 5: F1 score of 0.42181273302084843; loss of 0.06336357444524765; binary_accuracy of 97.98119068145752%
# Training for fold 6 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 57ms/step - loss: 0.1033 - binary_accuracy: 0.9626 - auc_24: 0.8722 - precision_24: 0.2599 - recall_24: 0.2766
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0680 - binary_accuracy: 0.9793 - auc_24: 0.9236 - precision_24: 0.6975 - recall_24: 0.2883
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0666 - binary_accuracy: 0.9794 - auc_24: 0.9283 - precision_24: 0.6998 - recall_24: 0.2950
# Epoch 4/5
# 331/331 [==============================] - 19s 59ms/step - loss: 0.0657 - binary_accuracy: 0.9795 - auc_24: 0.9315 - precision_24: 0.7018 - recall_24: 0.2990
# Epoch 5/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0652 - binary_accuracy: 0.9796 - auc_24: 0.9331 - precision_24: 0.7031 - recall_24: 0.3016
# precision_24 is 0.7048054933547974
# recall_24 is 0.3145981431007385
# Score for fold 6: F1 score of 0.43502002843069226; loss of 0.06342129409313202; binary_accuracy of 97.97946214675903%
# Training for fold 7 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 57ms/step - loss: 0.1032 - binary_accuracy: 0.9628 - auc_25: 0.8731 - precision_25: 0.2617 - recall_25: 0.2779
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0681 - binary_accuracy: 0.9793 - auc_25: 0.9233 - precision_25: 0.6977 - recall_25: 0.2880
# Epoch 3/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0667 - binary_accuracy: 0.9794 - auc_25: 0.9282 - precision_25: 0.7003 - recall_25: 0.2947
# Epoch 4/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0658 - binary_accuracy: 0.9795 - auc_25: 0.9310 - precision_25: 0.7020 - recall_25: 0.2990
# Epoch 5/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0651 - binary_accuracy: 0.9796 - auc_25: 0.9331 - precision_25: 0.7037 - recall_25: 0.3021
# precision_25 is 0.6888536214828491
# recall_25 is 0.3298610746860504
# Score for fold 7: F1 score of 0.4461033039736124; loss of 0.06328528374433517; binary_accuracy of 97.97437787055969%
# Training for fold 8 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 58ms/step - loss: 0.1043 - binary_accuracy: 0.9621 - auc_26: 0.8715 - precision_26: 0.2547 - recall_26: 0.2771
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0683 - binary_accuracy: 0.9793 - auc_26: 0.9225 - precision_26: 0.6968 - recall_26: 0.2879
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0667 - binary_accuracy: 0.9794 - auc_26: 0.9281 - precision_26: 0.7000 - recall_26: 0.2951
# Epoch 4/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0658 - binary_accuracy: 0.9795 - auc_26: 0.9309 - precision_26: 0.7012 - recall_26: 0.2986
# Epoch 5/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0651 - binary_accuracy: 0.9796 - auc_26: 0.9333 - precision_26: 0.7028 - recall_26: 0.3017
# precision_26 is 0.7361375093460083
# recall_26 is 0.288247287273407
# Score for fold 8: F1 score of 0.4142772146354354; loss of 0.063405342400074; binary_accuracy of 97.9846179485321%
# Training for fold 9 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 57ms/step - loss: 0.1033 - binary_accuracy: 0.9624 - auc_27: 0.8726 - precision_27: 0.2585 - recall_27: 0.2781
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0680 - binary_accuracy: 0.9793 - auc_27: 0.9237 - precision_27: 0.6976 - recall_27: 0.2880
# Epoch 3/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0665 - binary_accuracy: 0.9794 - auc_27: 0.9286 - precision_27: 0.7004 - recall_27: 0.2952
# Epoch 4/5
# 331/331 [==============================] - 19s 57ms/step - loss: 0.0657 - binary_accuracy: 0.9795 - auc_27: 0.9312 - precision_27: 0.7013 - recall_27: 0.2994
# Epoch 5/5
# 331/331 [==============================] - 19s 59ms/step - loss: 0.0651 - binary_accuracy: 0.9796 - auc_27: 0.9334 - precision_27: 0.7030 - recall_27: 0.3021
# precision_27 is 0.6910489201545715
# recall_27 is 0.32386815547943115
# Score for fold 9: F1 score of 0.44103847395946905; loss of 0.06374149024486542; binary_accuracy of 97.96994924545288%
# Training for fold 10 ...
# Epoch 1/5
# 331/331 [==============================] - 20s 58ms/step - loss: 0.1024 - binary_accuracy: 0.9628 - auc_28: 0.8736 - precision_28: 0.2618 - recall_28: 0.2771
# Epoch 2/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0680 - binary_accuracy: 0.9793 - auc_28: 0.9234 - precision_28: 0.6985 - recall_28: 0.2883
# Epoch 3/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0666 - binary_accuracy: 0.9794 - auc_28: 0.9283 - precision_28: 0.6994 - recall_28: 0.2950
# Epoch 4/5
# 331/331 [==============================] - 19s 58ms/step - loss: 0.0657 - binary_accuracy: 0.9795 - auc_28: 0.9313 - precision_28: 0.7014 - recall_28: 0.2994
# Epoch 5/5
# 331/331 [==============================] - 19s 59ms/step - loss: 0.0652 - binary_accuracy: 0.9796 - auc_28: 0.9330 - precision_28: 0.7028 - recall_28: 0.3019
# precision_28 is 0.735863447189331
# recall_28 is 0.28605639934539795
# Score for fold 10: F1 score of 0.4119666504700158; loss of 0.06390903890132904; binary_accuracy of 97.98063039779663%
# =======================================================================
# Training for Molecular Function
# Training for fold 1 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 58ms/step - loss: 0.1322 - binary_accuracy: 0.9490 - auc_29: 0.8563 - precision_29: 0.2357 - recall_29: 0.2950
# Epoch 2/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0813 - binary_accuracy: 0.9743 - auc_29: 0.9224 - precision_29: 0.6779 - recall_29: 0.3111
# Epoch 3/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0787 - binary_accuracy: 0.9747 - auc_29: 0.9293 - precision_29: 0.6855 - recall_29: 0.3238
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0776 - binary_accuracy: 0.9748 - auc_29: 0.9321 - precision_29: 0.6868 - recall_29: 0.3300
# Epoch 5/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0765 - binary_accuracy: 0.9750 - auc_29: 0.9350 - precision_29: 0.6900 - recall_29: 0.3352
# precision_29 is 0.7070431709289551
# recall_29 is 0.3393610119819641
# Score for fold 1: F1 score of 0.4586046002490291; loss of 0.07417357712984085; binary_accuracy of 97.54126071929932%
# Current best model for Molecular Function has an F1 score of 0.4586046002490291
# Training for fold 2 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 60ms/step - loss: 0.1319 - binary_accuracy: 0.9492 - auc_30: 0.8574 - precision_30: 0.2368 - recall_30: 0.2944
# Epoch 2/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0812 - binary_accuracy: 0.9743 - auc_30: 0.9226 - precision_30: 0.6763 - recall_30: 0.3119
# Epoch 3/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0788 - binary_accuracy: 0.9746 - auc_30: 0.9292 - precision_30: 0.6832 - recall_30: 0.3233
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0775 - binary_accuracy: 0.9748 - auc_30: 0.9326 - precision_30: 0.6871 - recall_30: 0.3301
# Epoch 5/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0766 - binary_accuracy: 0.9750 - auc_30: 0.9348 - precision_30: 0.6895 - recall_30: 0.3354
# precision_30 is 0.6995500922203064
# recall_30 is 0.34617987275123596
# Score for fold 2: F1 score of 0.46316003178608595; loss of 0.0739210918545723; binary_accuracy of 97.53738641738892%
# Current best model for Molecular Function has an F1 score of 0.46316003178608595
# Training for fold 3 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 58ms/step - loss: 0.1319 - binary_accuracy: 0.9494 - auc_31: 0.8571 - precision_31: 0.2384 - recall_31: 0.2951
# Epoch 2/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0811 - binary_accuracy: 0.9744 - auc_31: 0.9230 - precision_31: 0.6793 - recall_31: 0.3110
# Epoch 3/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0785 - binary_accuracy: 0.9747 - auc_31: 0.9299 - precision_31: 0.6861 - recall_31: 0.3236
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0773 - binary_accuracy: 0.9749 - auc_31: 0.9331 - precision_31: 0.6882 - recall_31: 0.3304
# Epoch 5/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0764 - binary_accuracy: 0.9750 - auc_31: 0.9354 - precision_31: 0.6898 - recall_31: 0.3350
# precision_31 is 0.6989678740501404
# recall_31 is 0.3420601487159729
# Score for fold 3: F1 score of 0.45933260146061283; loss of 0.07447200268507004; binary_accuracy of 97.5288987159729%
# Training for fold 4 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1348 - binary_accuracy: 0.9480 - auc_32: 0.8548 - precision_32: 0.2301 - recall_32: 0.2961
# Epoch 2/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0810 - binary_accuracy: 0.9743 - auc_32: 0.9235 - precision_32: 0.6778 - recall_32: 0.3107
# Epoch 3/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0786 - binary_accuracy: 0.9747 - auc_32: 0.9298 - precision_32: 0.6851 - recall_32: 0.3234
# Epoch 4/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0774 - binary_accuracy: 0.9749 - auc_32: 0.9329 - precision_32: 0.6889 - recall_32: 0.3304
# Epoch 5/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0765 - binary_accuracy: 0.9750 - auc_32: 0.9351 - precision_32: 0.6899 - recall_32: 0.3347
# precision_32 is 0.696456253528595
# recall_32 is 0.34070199728012085
# Score for fold 4: F1 score of 0.45756573099698566; loss of 0.07458820939064026; binary_accuracy of 97.52118587493896%
# Training for fold 5 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1318 - binary_accuracy: 0.9494 - auc_33: 0.8572 - precision_33: 0.2381 - recall_33: 0.2951
# Epoch 2/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0810 - binary_accuracy: 0.9743 - auc_33: 0.9235 - precision_33: 0.6778 - recall_33: 0.3110
# Epoch 3/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0787 - binary_accuracy: 0.9747 - auc_33: 0.9297 - precision_33: 0.6842 - recall_33: 0.3232
# Epoch 4/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0775 - binary_accuracy: 0.9748 - auc_33: 0.9327 - precision_33: 0.6864 - recall_33: 0.3297
# Epoch 5/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0766 - binary_accuracy: 0.9750 - auc_33: 0.9349 - precision_33: 0.6900 - recall_33: 0.3354
# precision_33 is 0.6922547817230225
# recall_33 is 0.34525740146636963
# Score for fold 5: F1 score of 0.460729215450052; loss of 0.07488247007131577; binary_accuracy of 97.51983284950256%
# Training for fold 6 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1307 - binary_accuracy: 0.9499 - auc_34: 0.8588 - precision_34: 0.2415 - recall_34: 0.2953
# Epoch 2/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0809 - binary_accuracy: 0.9743 - auc_34: 0.9236 - precision_34: 0.6785 - recall_34: 0.3117
# Epoch 3/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0787 - binary_accuracy: 0.9746 - auc_34: 0.9294 - precision_34: 0.6836 - recall_34: 0.3235
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0774 - binary_accuracy: 0.9748 - auc_34: 0.9330 - precision_34: 0.6875 - recall_34: 0.3304
# Epoch 5/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0767 - binary_accuracy: 0.9749 - auc_34: 0.9346 - precision_34: 0.6888 - recall_34: 0.3348
# precision_34 is 0.699805736541748
# recall_34 is 0.33976900577545166
# Score for fold 6: F1 score of 0.4574414703665381; loss of 0.07429736852645874; binary_accuracy of 97.52680659294128%
# Training for fold 7 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1303 - binary_accuracy: 0.9496 - auc_35: 0.8591 - precision_35: 0.2396 - recall_35: 0.2950
# Epoch 2/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0809 - binary_accuracy: 0.9744 - auc_35: 0.9238 - precision_35: 0.6786 - recall_35: 0.3119
# Epoch 3/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0788 - binary_accuracy: 0.9746 - auc_35: 0.9294 - precision_35: 0.6836 - recall_35: 0.3236
# Epoch 4/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0775 - binary_accuracy: 0.9748 - auc_35: 0.9325 - precision_35: 0.6871 - recall_35: 0.3296
# Epoch 5/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0767 - binary_accuracy: 0.9749 - auc_35: 0.9346 - precision_35: 0.6880 - recall_35: 0.3352
# precision_35 is 0.6752920746803284
# recall_35 is 0.37065309286117554
# Score for fold 7: F1 score of 0.478608446852395; loss of 0.07473502308130264; binary_accuracy of 97.52187728881836%
# Current best model for Molecular Function has an F1 score of 0.478608446852395
# Training for fold 8 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1346 - binary_accuracy: 0.9484 - auc_36: 0.8536 - precision_36: 0.2326 - recall_36: 0.2960
# Epoch 2/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0813 - binary_accuracy: 0.9743 - auc_36: 0.9225 - precision_36: 0.6785 - recall_36: 0.3104
# Epoch 3/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0789 - binary_accuracy: 0.9746 - auc_36: 0.9290 - precision_36: 0.6838 - recall_36: 0.3222
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0775 - binary_accuracy: 0.9748 - auc_36: 0.9324 - precision_36: 0.6873 - recall_36: 0.3300
# Epoch 5/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0767 - binary_accuracy: 0.9750 - auc_36: 0.9347 - precision_36: 0.6897 - recall_36: 0.3344
# precision_36 is 0.7105169892311096
# recall_36 is 0.3347564935684204
# Score for fold 8: F1 score of 0.45509654621443024; loss of 0.07421300560235977; binary_accuracy of 97.54008650779724%
# Training for fold 9 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1306 - binary_accuracy: 0.9500 - auc_37: 0.8584 - precision_37: 0.2415 - recall_37: 0.2943
# Epoch 2/5
# 218/218 [==============================] - 15s 68ms/step - loss: 0.0808 - binary_accuracy: 0.9743 - auc_37: 0.9240 - precision_37: 0.6786 - recall_37: 0.3109
# Epoch 3/5
# 218/218 [==============================] - 17s 77ms/step - loss: 0.0787 - binary_accuracy: 0.9747 - auc_37: 0.9296 - precision_37: 0.6844 - recall_37: 0.3231
# Epoch 4/5
# 218/218 [==============================] - 16s 73ms/step - loss: 0.0772 - binary_accuracy: 0.9749 - auc_37: 0.9333 - precision_37: 0.6888 - recall_37: 0.3310
# Epoch 5/5
# 218/218 [==============================] - 13s 60ms/step - loss: 0.0765 - binary_accuracy: 0.9750 - auc_37: 0.9351 - precision_37: 0.6899 - recall_37: 0.3349
# precision_37 is 0.7019795179367065
# recall_37 is 0.33617082238197327
# Score for fold 9: F1 score of 0.45462592974278415; loss of 0.07446350157260895; binary_accuracy of 97.52495288848877%
# Training for fold 10 ...
# Epoch 1/5
# 218/218 [==============================] - 14s 59ms/step - loss: 0.1321 - binary_accuracy: 0.9492 - auc_38: 0.8569 - precision_38: 0.2374 - recall_38: 0.2960
# Epoch 2/5
# 218/218 [==============================] - 13s 59ms/step - loss: 0.0810 - binary_accuracy: 0.9743 - auc_38: 0.9234 - precision_38: 0.6787 - recall_38: 0.3112
# Epoch 3/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0786 - binary_accuracy: 0.9747 - auc_38: 0.9297 - precision_38: 0.6847 - recall_38: 0.3231
# Epoch 4/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0774 - binary_accuracy: 0.9748 - auc_38: 0.9329 - precision_38: 0.6877 - recall_38: 0.3300
# Epoch 5/5
# 218/218 [==============================] - 13s 58ms/step - loss: 0.0764 - binary_accuracy: 0.9750 - auc_38: 0.9353 - precision_38: 0.6909 - recall_38: 0.3354
# precision_38 is 0.7065880298614502
# recall_38 is 0.3416927456855774
# Score for fold 10: F1 score of 0.4606323222248016; loss of 0.07371457666158676; binary_accuracy of 97.54449129104614%
